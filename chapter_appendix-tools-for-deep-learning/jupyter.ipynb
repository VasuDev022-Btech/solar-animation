# %% [markdown]
# # SET **OPERATORS**

# %% [markdown]
# **DUPLICATE**

# %%
a={1,2,3,4,5,5}
a
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# **ADD**

# %%
a={1,2,3,4,5}
a.add(9)
a
# Out:
# {1, 2, 3, 4, 5, 9}

# %% [markdown]
# **UPDATE**

# %%
a={1,2,3,4,5}
a.update((6,7,8,9))
a
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %% [markdown]
# **CLEAR**

# %%
a={1,2,3,4,5}
a.clear()
a
# Out:
# set()

# %% [markdown]
# **REMOVE**

# %%
a={1,2,3,4,5}
a.remove(5)
a
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# **DELETE**

# %%
a={1,2,3,4,5}
del(a)

# %% [markdown]
# **POP**

# %%
a={1,2,3,4,5}
a.pop()
a
# Out:
# {2, 3, 4, 5}

# %% [markdown]
# # **DICTIONARY**

# %%
a={}

# %%
a.update({'name':['a','b']})

# %%
a
# Out:
# {'name': ['a', 'b']}
